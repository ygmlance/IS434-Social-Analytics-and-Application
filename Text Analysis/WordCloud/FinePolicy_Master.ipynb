# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

import nltk
from nltk.corpus import wordnet as wn

import gensim
from gensim.models import LdaModel
from gensim.corpora import Dictionary

import re
import string
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer

import unicodedata
from textblob import Word

# %%
one_fine = pd.read_csv('master/master_policy1.csv')

# %%
one_fine.head()
# Out:
#     platform      post_id          username  \
# 0  instagram  B--cvRQHJRp  photographyholic
# 1  instagram  B-9dOShHqC-      mothershipsg
# 2  instagram  B_Aeqc0nnVm      mothershipsg
# 3  instagram  B-_uYTVAjLI            sgagsg
# 4  instagram  B_HnKCNHUxp    sgmemetextbook
#
#                                                 text
# 0  singapore now it is mandatory with immediate e...
# 1  just in first time offenders will face a s 300...
# 2  first time offenders will face a fine of below...
# 3  hello police please fine this sound by @mingwe...
# 4  the 600 the government gave out on 14 4 2x 300...

# %%
one_fine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1250 entries, 0 to 1249
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   platform  1250 non-null   object
#  1   post_id   1250 non-null   object
#  2   username  1250 non-null   object
#  3   text      1250 non-null   object
# dtypes: object(4)
# memory usage: 39.2+ KB

# %%
fine =list(one_fine['text'].dropna())

# %%
fine
# Out:
# ['singapore now it is mandatory with immediate effect for everyone to wear a mask when they step out of your house as part of stricter measures to curb the further spread of the coronavirus those who do not risk a 300 fine for first time offenders there are exemptions for those engaging in strenuous exercise and children below the age of two as medical experts recommend against them wearing masks national development minister lawrence wong said at a media conference on tuesday april 14 please stay home sgunited covi d19 singaporetogether sgunited singapore singapore2020 photographyislife streetshared instagram artofvisuals exploresg instasg visualambassadors whatissingapore iluvsg citygrammers kilogrammerz madaboutsingapore2020 streetphotography streetshated thankyou singapore singapore2020 madaboutsingapore2020c circuitbreakersg',
#  'just in first time offenders will face a s 300 fine photo via suhaimi abdullah getty images link in bio',
#  'first time offenders will face a fine of below s 10 000 imprisonment of up to six months or both image via enterprise singapore link in bio',
#  'hello police please fine this sound by @mingweirocks cbchallenge',
#  'the 600 the government gave out on 14 4 2x 300 fine',
#  'a fine of s 300 will apply for non compliance with the new mask rule those who continue to disobey all safe distancing measures including the use of masks may be fined s 1 000 and face possible prosecution linkinbio to learn more',
#  'the police said that they are aware of messages circulating on text messaging platforms that give the false impression that they are proactively doing such checks during this period when people are told to restrict their movements this is not true the police urge the public not to spread unsubstantiated information which may cause public alarm they added the police explained in a statement that they were responding to a call for assistance regarding a family dispute at a residence in jurong west police officers then discovered that there was a gathering of family members the warning was issued to the two people who were not residing there and were not there for essential purpose linkinbio to read more',
#  'before 7am should be fine',
#  'this method of ghost cannot be done in reddot cauz our gamen is worrylah there no incomes to collect back they only thing they know is fine them this bring back some income for them u got it',
#  'on jan 2020 don t wear mask if you re fine on apr 2020 don t wear mask you ll be fined',
#  'breaking the measures attracts a fine so please kiddos stop joking about removing the tapes surrounding the playgrounds it is not a joke at all it s an offence do stay home and don t let your booming affect your grandparents they are the boomers take care',
#  '@snowbreeeze let them do it then their parents pay the fine and no new smartphone for them',
#  '@siegdelacroix idc who pays the fine i worry it becomes a trend that everything is a joke sad kids',
#  'there are lots of ppl in the parks and pedestrian walkways cycling running and walking without masks come and go pass you in close proximity without warning your probability of being infected in these public places is pretty high if you see a runner or a cyclist or a pedestrian without wearing mask is about to pass you do save yourself and keep a distance i spotted some irresponsible shoppers in a mall pulled down their masks to eat or talk over their phones while walking',
#  '@manmanbro168 but still no official report to support the allegation maybe true maybe not nobody s know the real numbers this is really become pandemic hopefully everything s going to be fine soon take care urself family s k',
#  'ehh knn walau last warning sia',
#  'these people stay at tanjong rhu condo so rich fine them la go and fine grab riders 1meter rule fine middle class peeps at geylang market',
#  'please fine my sister please',
#  'should be a 500 fine to further force people to follow rules and for last part no need to show kindness just report them straight away',
#  'me walking downstairs to throw trash 300 fine cool man',
#  '@gabl333 ya jogging is fine as long as you ain t near anyone not from your household either way anyone stay at home too long also will siao so that s why government still allows solo exercising outside',
#  '@jokerpills exercise has to be consistent to be effective i would jog at home but i dont have a treadmill anyways i think jogging should be fine wont even be anywhere near anyone anyways',
#  '@rosevollo spacious parks should be fine la as long as you exercise alone or with family members but should keep a distance also',
#  'let s not just focus on the daily numbers as i feel we are all infected in one way or the other covid19 is just a warning of what is more to come if we ignore the real issues regardless of race and religion this pandemic will not go away until we realised each of us is infected somewhat it s really up to us when we want this pandemic to end',
#  '@mjjunh well lets backtrack again and examine ur tone at the end of the day what did the other parties do sigh im not exactly taking any stance lol why shd i bother debating with u abt this as if knocking some sense into ur head will satisfy me but the govt is doing fine except we shd be more critical in our outlook anyways',
#  '@hbethyname you don t know anything don t come here talk cock la i am just stating the facts as facts don t lie the minister really tell people don t wear mask if you are not sick then later discover wrong quickly ask people wear different day say different things old people will confused you don t give time for people to digest straight fine people how can you want a baby also need to wait 9 months',
#  '@fattfries ofc ppl won t listen singaporeans mah and this is why fine is quite effective here',
#  '@mrrespectablespectacle hahaah i m fine don t worry im just brutally frank',
#  'fine the penguins they breaking cb rules',
#  'they shld kena fine for not wearing face mask',
#  'fine then 300 la',
#  'oh my goodness just fine them already for being so cute',
#  'wheres the social distancing time to fine them 300',
#  'fine them each 300',
#  '@id1oti6 animals can get the virus and spread to us 2 we have to fine them 300 dollars',
#  'january 2020 dont wear mask if you re fine april 2020 dont wear mask you ll be fined',
#  'the indian guy in the back did not wear mask he will get fine',
#  '@guitarize67 6 2k people fyi if not some ppl are gonna start a fight and say 6 2 where da hell govt say 6 2k fine',
#  '@ihopeyoufallintoanavocado it can be just need to use the right materials now with new law wear mask is better than getting fined i suggest you make one and wear if you wanna go out 1st offence fine 300 2nd time fine 1000',
#  '@aiman jabba if you never wear mask but caught by nea officers start to run jogging then they cannot fine if you are running lol',
#  'holding a press conference is not an exception right fine the ministers pls',
#  'already people are poorer by lockdowns now sit also fine don t wear mask also fine didn t stand 1 m also fine etc frankly i rather get covid 19 then i get paid',
#  '@megcharlotte even they did not give us the 600 and if one don t comply with the laws they can still fine us so we need to know the 600 indeed is a help for citizens to go through this tough time 300 is to force citizens to stay home and not being infected if u stay home and or obey the law if need to go out then u won t need to depart the 600 from your pocket le',
#  '@ccthecatcosmia it s illegal to go out wo a mask hope you don t do so or risk a fine have you read the press release or not',
#  '@fucksnowbreeeze indonesians are not a race i m fine with malays indians with indian privilege pls stay away and foreigners aren t a race either see you are owned',
#  'i m starting to make funnier zoom video backgrounds for classes so this is fine',
#  'wah if extend goodluck to those who are taking their finals this year but dudes if yall dont want this to be extended just do your part to stay home and stop loitering outside just rmb go out wear mask police see you nvr wear mask kena fine not my problem also',
#  '@_whydoiexist okay then that s fine hahaha i m rotting but i m trying my best to practice my skills set every week but i need all those ingredients help',
#  '@shervonnnnn erm who ate bats in the first place who cover up the outbreak news since nov 2019 who did not impose global outbreak warning early thats some question to you on why your on hbl now and why i am on wfh too',
#  'kids seeing this i guess eating soap from bubble dispensers are fine',
#  'fine them for not practising social distancing',
#  '@junn_weii no they staying in same household so its fine',
#  '@shesraining oh yeah i forgot fine them for not wearing mask outside',
#  'ya thank you very much next day fine 1200 for no masks on',
#  '@bee_qiun what happened last week is very different from now last week no 300 fine this week got so imagine how things were 4 weeks ago when he was in uk very very different',
#  'lmao his parents want him to be the david of the davids lol jokes aside bad idea to party but at least it s a warning to young oeople',
#  'instead of fining these delivery guys who are trying to fill our stomach during such times being in risk since they re always expose to the public why not just come over and fine my neighbour who kept on every few minutes come out of their house and kept going in and out nonstop kept on turning their lock even when i m in my room with door closed could still hear it and another one who kept on slamming the riser door and charge them 300 each time they go in and out and another for slamming the riser door probably they could earn more just by giving fine to my neighbours',
#  'fine then',
#  'we cannot afford to be lenient to those who are not considerate if we don t start to issue fines more ppl will take it for granted that it s only verbal warning and this one month of cb will be wasted and needs to be extended this will only caused more inconveniences for all the riders should also spare a thought for their customers who are receiveing the food deliveries and the riders own families not to overlook the safe distancing to protect themselves this is not the time to be lenient anymore',
#  'doesn t matter if you are a delivery guy or a customer you flout rules you will be fine no negotiations',
#  '@junjiecool i think these delivery guys did well without them most family will not be able to have their hot nice food delivered so at least they have a warning for first offence remember it s very hot and frustrating outside however i also hope these delivery guys will be properly protected as they are more vulnerable to be spread the virus as they are out most of the time be careful guys',
#  '@snowbreeze eliminator ban them is not enough fine them would be better',
#  'truly a fine city but it s for the best i guess',
#  '@keeneyongkaiyuan hi im amazed by your biasness towards china you do realise that they arrested the doctor who started warning about this virus and asked him to shut up few weeks ago a female doctor who claimed that she was the 1st person to alert other healthcare personnel about this virus spoke against the chinese regime guess what she is missing now are you blind this is the ccp we are talking about who declared this as a pandemic 57 days after its spread to 80 over countries affected more than 180 000 people they changed the name to covid 19 curiously after they went beijing for a talk with chinese authorities almost the whole world is asking answers from who china even their so called act of help to europe is with damaged goods they are even attacking african citizens now and here we still have a bunch of clowns in singapore still kowtowing to china fascinating',
#  '@keeneyongkaiyuan curiously did you read up on the doctor who warned all his colleagues and was given a warning and the citizen journalist who was reporting what he saw',
#  'dunno what stricter rules government would say let s do a lockdown that is not called a lockdown we will close all food centers and only allow deliveries no leaving house allowed unless you wanna kena fined 1st warning immediately pay 10k amazing',
#  'the number of people saying it s fine less local cases bro these workers came far from their homeland just to build this nation now they re affected without their family c mon',
#  'this is what happens when u neglect the living environment of the foreign workers the spreading will be much faster within the foreign workers because of their bad living environment community cases might seem kinda stable but we cannot downplay the situation just because of this i feel we still need to treat the situation seriously and try to resolve it as soon as possible by playing a part by going out only when necessary and stay at home as far as possible hais hope everything will turn out well and fine for everyone every single one sooner',
#  '@matthewxudong i see a weakness in your argument you seem to lie heavily on the wear a mask only if you are sick now we do not have a mass mask production team and we had to rely on importing them before we have one running well those helping us with the masks needs it for themselves as well the government havetold us to stay at home and go out if we have to adviced but not enforced people took that for granted and continued going out enjoying life now whose fault is that we arent giving as much cooperation as the government require us to do even when it is enforced people are still not listening a 300 fine isnt even enough to scare them people with the virus and doesnt show symptoms are very unlikely to spread the virus how do you spread the virus if you dont sneeze or cough right the only way is to share something he she have consumed even then the government have told us to minimize contact with one another knowing the virus is alive and about everyone should understand the need to restrain themselves from having any bodily fluid contact with anyone but their family i agree things could have been done differently but the government have done a lot to help us but we are not helping ourselves you say you dont see the reusable masks being used i saw many people using it in the malls the moment they started handing it out i saw more people using reusable masks than the surgical ones whatever it is the important thing now is people should be at home and only going out if needed people have suddenly became healthy and going out to exercise no stop that as it defeats the purpose of the cb',
#  'it s fine i don t order mac anyway but good call on banning walk in takeaways',
#  'i am very upset that such people are demanding things from medical team when he seems fine we are overworked and shorthanded why because of irresponsible humans blame them and dont blame the medical staff got place for you to sleep eat play game and use the toilet what about us we rush like mad sleep so little no time for our families for spoilt brats like you imagine the stress we are feeling working at frontline i feel hurt that i am actually helping spoilt brats',
#  '@dearlianne i agree we frontline work to the max alr i feel and see him here is fine and do not need any medical attention fever will come and go as singapore is hot if its serious an ambulance will be called for',
#  '@reubenchen yes no need but if you tske taxi or grab or wtv public transport you have to wear if not you will get fine 300',
#  'just wish covid will go off soon take care of each other be nice be kind be compassion bring extra disposible masks offer to anyone who s not wearing so tht they wont get fine 300 if you have old neighbors check up on them when going for our grocery runs we shld remember them stay safe stay healthy everybody thank you team @mothershipsg for the interviews and daily scoop',
#  '@lepersftw first you say xenophobia then you say poor sadly its the latter being poor is fine corruption and incompetence isn t',
#  '@scizor 101 its fine because all dormitories are under lockdown so these numbers while they can continue to increase are under control',
#  'he gonna kena fine',
#  'omg he sat on the fine seat',
#  '@open_sniff fine sex',
#  'sadly malaysia fine more here is 1000myr',
#  '@sgagsg actlly shld have an app so anyone can take pic of these cb and authorities can public shame them fine them',
#  '@melissacwl_ yeahhh that s fine haha but some of em are not following the rules',
#  '@fishhorizontal last warning sia hahahaha',
#  'raise your hand if you are the idiot who intentionally want to extend cb for defying the cb rules by meaningless gathering despite warning elder not included',
#  'this is fine',
#  '@_isabella_yap_ oh then its fine',
#  '@bellyturnreal i say i m fine but i m not fine',
#  'then singtel working perfectly fine',
#  'put your dns to google 8 8 8 8 and you ll be fine',
#  'not fine',
#  'really ah my internet working fine as usual',
#  'circles and myrepublic are fine tho',
#  'lol my internet is fine',
#  'was playing animal crossing everything is fine very smooth hahaha',
#  'my wifi is perfectly fine tho',
#  '@vxnessaaaah starhub not fine',
#  'mine was fine',
#  'hahaha i use @circleslifesg data and it s perfectly fine',
#  '@milomikoo what mine is working fine though',
#  'my internet is working perfectly fine nani',
#  '@qyy_yue yao my wifis fine and im using starhub',
#  'mine s fine',
#  'mine was fine',
#  'what im viewimg this post right now seems fine leh',
#  'hello police please fine this guy',
#  '@moist _ mizu i ve used google translate when learning mandarin chinese btw i highly recommend pleco app malay and tamil chinese sentences just sound off because of how english phrases are made but sentences are fine malay also a bit weird i find eng indon much better then just swap the indon words for more relavant malay terms like bisa boleh tamil tho is a hot mess bangladeshi languages like tamil has a cancerous but very rich and complex grammar slightly worse than korean japanese if you know em the biggest issue is the word order is different verb goes to end instead of in middle the second issue is that like english has ed and ing tamil ik the focus is on bangladeshi but it relates there is a lot and it includes the tense continuation passive active marker whether it s not transitive who is doing it is it girl guy thing someone respectable japanese and korean speakers call this honorifics and singular plural is it us you all them all those things all a simple sentence like i like this in malay is aku suka ni in chinese is wo xihuan zhege but tamil is ennakku ithu pidichirukku en me obj form akku towards me ithu this pidi like chi currently used to bridge secondary verb to the primary modal verb following iru have kku currently but that s spoken tamil like this ain t rite vs this is not rite in written tamil which you ask google translate is ennakku ithu pidithirukkirathu which is different in the verb suffix chi is now tthi since the consonant changes when spoken like apa vs ape kku is now kirathu which is kir present non continuous tense and athu which implies an non human object ithu this is performing the action this should make your head scratch because is it not me who is liking the object so i m doing it ye that s the problem you dont like something you may love something but it s pretty odd no kink shaming tho so only having objects being liked by you which means the word is not passive but intrabsitive like i ran vs i ran the machine which is differrnt in tamil naan oodinen vs machine ai otdinen',
#  '@vaderhound later kena fine how',
#  '@danialdave bro you sure or not haha my mom and aunt are in malaysia as well hope you guys are coping fine take care man',
#  'as the public transport is equip with camera why not fine those who does that',
#  '@nea_sg should fine them',
#  'fine 600',
#  'gains fine my mans has the balls and has the guns i see hes practising social distancing while maximising gains bravo to him @1man_13east',
#  '@yxngann what taking you fine me for what i m not the trespasser',
#  '@dear picture diary18 i fine you then you know',
#  'kena fine then learn bah singaporeans',
#  'u ever know why they kaypo cos they care for u but u don t even give a damn about it and repeatedly say why i kaypo and it s dangerous u may get fine or arrested',
#  'when they get fine',
#  'we can thanks them later when cb is over law is law it s time to fine them 300 each thank you',
#  '@yisforyoki eh that s true plus the 300 fine is already scary enuf',
#  'hahahahahaha creative but yeah unlikely to work here in sg in singapore the best way to control behavior is to levy a huge fine often compliance follows quickly',
#  'singaporeans not scared die scared lose money so i crease the fine',
#  'just increase the fine to 1k and do not give out any more warning',
#  'i hope gov dont straight away give fine but to see situation first sometime ppl may not know where to q or the walkway is narrow',
#  'is that lady in white paying her fine through paylah',
#  'fine her she already got money bank in see she real or lie',
#  'just enforce fine otherwise no all will follow',
#  '@seexianyang tats y we need to hv common sense when dealing with such group of people not just enforce and fine them blindly worst labeling them with harsh title',
#  '@teh_peng there s no way to educate them if not they are not being call mentally ill while many either comes from poor family if you fine them it makes her family financial wealth in greater risk and they will suffer further more in such sucks period let s pray policeman have mercy for them',
#  'seriously some p brain ppl are challenging the regulations shld fine them',
#  'why fine 300 should fine 300 x number of cases',
#  '200 300 60 000 i hope government use the fine money to fund research for cure',
#  'idiot report him n give him a heavy fine pple is just doing their job show some respect',
#  'lol take photo for what not like shes gna get out of paying her fine @dnvnlm',
#  'just fine her',
#  'fine her 10k and send back waste time',
#  'oh um may we fine u continue recording ha ha wow so lenient so do i wana eat there since no one around',
#  'local can have her shamed publicly as well as fine and jail foreigner all of the above then throw her out of the country',
#  'dat must be sum fine ass bak kut teh alan',
#  'that is one fine ass bak kut teh',
#  'he breached the 14 day stay home notice cause that is one fine ass bak kut teh',
#  'should fine him and sentence to death',
#  'hope every thing is fine',
#  '@uaremysunshinee__ the sad part is he may be wealthy enough to afford the 300 fine and not feel any remorse about what he did',
#  '@the_ray_fan_club so all s good balances out fine for me',
#  'cb kene fine cfm teros yes i give a fuck @_ 1zzv',
#  'i already saw this in tiktok this indian guy don t want listen to the rules go jail or kena fine don t care lah mampus already',
#  '@exorxcism he brisk walking so it s fine but even if he s wrong that why we got law enforcement the uncle say one time can alr follow for what',
#  'fine your mother la @cameraman beat u outside if u do this to others',
#  'and if he s not a police officer and he said you want i fine u 300 dollars its breaking the law bcs ur impersonating a police officer',
#  '@im_6ix_9ine im sure he wear by the sound of his voice but the way he approaches the old man isnt a polite way he is not the police officer or what he has no right to say such word as uneducated worst he say you want me to fine u 300 or not who tf is he to say tht the police he s the uneducated one',
#  '@fahimahlatiff i agree he isn t the police officer or anyth saying such words like uneducated towards the old man thts disrespectful he even say you want me to fine u 300 or not like tf he is not a police officer',
#  'knn he fine what fine he officer meh ppl daiji wan huanlo',
#  'as long got maintain a safe distance then it s fine',
#  '@the_chained_monkey ikr look at where the us is right now when trump prioritize business and economy over health and well being of americans you are right this 300 fine should be in jan or february tbh if lky is still around he would have done circuit breaker right from the beginning of the first or 10th case in singapore',
#  'is it clear if the ministers are campaigning or checking if the people on the ground are fine',
#  '@limqingquan i think they should be staying home unless it s absolutely necessary let the experts handle things check if everything is fine',
#  'don t people have better things to do then reading the fine prints of these numbers',
#  'not a bad idea to deter people to be honest',
#  'that 40bn needs to come from somewhere',
#  'install erp at the lifts and stairs so that no one will go out for fun',
#  'this is actually quite funny',
#  'imagine if they implement this in the us',
#  'not bad everyone confirm guai guai stay home lol',
#  'what a solid idea',
#  'when it becomes 8888 cases can i telll the officer that i saving the money for his wedding angpao s',
#  'that s a unique way deterring people a more pragmatic solution and it hits home to people the consequences of their actions',
#  'genius solution imo',
#  'should implement that in malaysia our police are still arresting anywhere between 700 1k idjits a day who can t sit still at home it seems',
#  '1 0 2 source code https github com fterh sneakpeek contribute https github com fterh sneakpeek',
#  'how about a of your income set to a minimum amount number of covid19 cases',
#  'nice better still link this to all those that are tested and suspected cases and there will not be any social distancing problem',
#  'make them pay for the cost of treatment for those who are in the hospitals and care facilities now',
#  'the fine should be more than the free money the gov is giving us',
#  'your reading comprehension fail is it my original comment was to address that it s unfair to charge only 300 and it should be pegged to income ability to better deter infractions notice i didn t say income in 2020 but 2019 this is in reference to the comic s suggestion to peg the fine at some semi arbitrary number of the covid 19 cases then you come in with a sarcastic diatribe about asymptomatic carriers and professions in critical services and i explained that we re like minded about taking this seriously and you replied with some illogical statement about me lecturing you smh',
#  'and take 75 of that fine give to front line workers',
#  'not for the first hundred or so would be like a early bird discount to them 0',
#  'this is why they let the fw dorm cluster happen s',
#  'at this pace govt will probably break even',
#  'hold it right there satan',
#  'probably the only one that is a creative and b has some form of comedic timing and punchline',
#  'they would clear up their national debt within no time if they actually enforce it like us but half of the average citizens will just end up in jail since they can t pay their fines',
#  'police officer will confirm say you can give me the angpao now',
#  'that s a great idea',
#  'no need your lecture thanks wtf lol you started the discussion and you re rage quitting because you re feeling lectured',
#  'ya so sue me',
#  'the first few hundreds already got warning instead of fines x',
#  'incorrect after doing a few quick maths 40 billion dollars divided by 5 7 million population is about 7000 dollars worth of fine if everybody in singapore got fined once and then twice it is still not enough to cover that 40 billion',
#  'the problem being that the us s national debt is mainly made up from bonds they issue and the vast majority of debt is actually owned to itself',
#  'yes but if more people got fined means more people are going out which lead to more people get infected leading to more cases which means fine amount would increase',
#  'are you saying the singapore government can t write enough fines',
#  'actually you should use the sum of arithmetic sequence if the fine increase by 1 each time you ll just need 282 843 to hit 40bn in fines n 1 n 2 40 000 222 746',
#  'so it lead to the us threatening to crash the us economy right',
#  'yea you know it https imgur com a 6ueu2oz',
#  'hahahaha yah im a slave to cat masters',
#  'arrest immediately for being too cute',
#  'i bet it will run away when the popo comes what a pussy',
#  'penalty for flouting rules no scritches for 3 months',
#  'sir stop sir',
#  'cats are assholes ahahah but so cute',
#  'dawwwww 3',
#  'what are you taling about i just see a part of the chess table on a seat',
#  'its free real estate cat probably',
#  'but she is wearing fur suit to protect against skin contact so it is fine',
#  'hello polis',
#  'since all the yp gone cat can take their place',
#  '300 meows please thanks',
#  'the matching colours are so spot on reminds me of the white stripes',
#  'how dare the cat break the law he is putting everyone of us in danger where is his mask why is he hoarding seats marked x i will fine him and call the police s manager for not arresting that evil cat',
#  'what cat where is the cat all i can see is another big checkers board with 2 ears 2 eyes 1 pink nose 1 mouth and 1 long black tail on the red seat looking at you and it will meow back at you if you touch the big checkers board',
#  'wah this cat really attitude problem hope she can afford the 300 fine p',
#  'r meow_irl',
#  'this is mews worthy',
#  'r catloaf',
#  'yup thats a fine kitty alright',
#  'did you pet the cat',
#  'which part of yishun',
#  'cb they better fine that cat horr',
#  'hello polis',
#  'kill it for oh wait it s yishun cat dead soon anyway',
#  'the purr fect crime',
#  'i don t want to be an accomplice to a crime',
#  'is this near the cage basketball court',
#  'paid cat tax',
#  'r cursedcomments',
#  'why cat calling',
#  'this is a meowstrosity',
#  'literally a catastrophy',
#  'i imagine with how you both reacted to finding out you live closeby you two probably would avoid we call that social distance now each other anyway lmao',
#  'inb4 repeat offenders complain that the fines are too expensive because they got no income',
#  'thats why we can t expect the entire population to be treated like a reasonable adult',
#  'didn t someone suggest predict this in an earlier thread we always make fun of the govt for making us a fine city but the truth is we as citizens always get the govt we deserve',
#  'oh good no income can stay at home or serve jail time in lieu of fines all 3 meals paid for save money',
#  'and that s how our govt manage to get back the money given out during the 3 budgets',
#  'seriously bruh human race is under threat from an epidemic and you are saying you can t sacrifice your habit to exercise outdoors if you don t know indoors exercises there are tons on the web to help you get through and those indoor exercises are no joke it can rip you as equally good as the outdoors ones',
#  'if you run fast enough',
#  'good one at last',
#  'ikr easy',
#  'i know the need to obey all the rules but there are just too many new rules coming out in these few days i am quite worried that elderly people who do not have access to news may not be able to adapt to the new rules so fast and get fined how do they identity properly who are the real ones who can fine them and who are the scammers on street',
#  'next time lead with that',
#  'pls tell your parents and grandparents to stay at home don t get fined for nothing',
#  'thanks for clarifying',
#  'before this got damn lot of covidiots stubborn dont want abide cb rules coz they not scared of warning now that the government step up i guess situation should be better',
#  'nah just their gahmen bro',
#  'pakchik pekchek liao',
#  'no income then government just take away the 300 from your solidarity payment lorh',
#  'are you fucking dumb lol edit fuck me you re 34 years old and can t differentiate between essential workers and people who decide to go out and loiter for no reason without safe distancing',
#  'ayy you re the first person ever to wish me my cake day in 3 years thank you very much 3',
#  'give the companies not the workers',
#  'to be fair many european countries are enforcing lockdowns with fines and judging by the number of people who were out in my corner of cambridge today because it s the hottest weekend since last summer i m all in favour of it just shows it s not a singaporean thing',
#  'govt here s 300 but if you go out with your friends you give me back the 300',
#  'some people don t want to give up their outdoor exercise privilege',
#  'then after awhile you have to swim fast',
#  'going by the number of people that fail 2 4km ippt no they don t run fast enough',
#  'the only ones who need to constantly play catch up with the rules are those who are constantly walking on the edge those who keep themselves well within the safe zone don t even need to bother following the news tbh the only thing that s being changed is that what we can or can t do is becoming more and more explicitly defined because a small minority of bad eggs are basing their decision making not on whether it benefits society or not but on whether it is legal or illegal',
#  'the reason for raising the alarm gradually was literally so that people have time to adapt and that when greater measures are imposed i e now there shouldn t have been a need for heavy enforcement because it is an expected progression and it s not like the govt has been trivialising the severity of the spread or that they ve continued encouraging people to meet each other visit densely populated areas etc ever since the second wave came in mid march they ve already signalled companies to have their employees work from home wherever possible prepared parents for the possibility eventuality of their children having lessons online and implemented many other distancing measures sure some would argue that these measures should ve been better enforced instead of it just being voluntary but had those measures been adhered to diligently i d think that we wouldn t need to get to this point you re also assuming that such problems of non compliance wouldn t have occurred if we had raised the dorscon and had implemented a lockdown from the beginning i can t bear to imagine the throngs of people rushing to ntuc ikea toys r us etc just before the lockdown and the sheer number of people losing their jobs income unnecessarily because companies wouldn t have had the time to figure out appropriate action plans blaming the government for not locking down the country earlier also insinuates that most if not all residents are too stupid and dumb to proactively carry these measures out on their own and before you attack me for being some pro govt pap dog i can also be critical of the govt if their actions warrant criticisms for example the current situation at the dormitories was absolutely avoidable like whose idea was it to house hundreds of thousands of workers in confined spaces without thinking that if just one person has the virus it s game over for the place and why is it that this issue never crossed the minds of anybody in the taskforce before it had to come to this so you see there are many other aspects of the govt s response to the virus that one can be critical of but blaming the govt for residents non compliance of the measures is just a bit too far fetched to me',
#  'the rule simply stated to stay home unless your life depends on it',
#  'and it s not as if singapore doesn t have one of the worst income divides in the world weve also seen the hundreds thousands of people who have been stood down or have lost their jobs this is very worrying indeed',
#  'i hear you but hor let them downvote lor lor wahahaha what s gonna happen i still sleep soundly at nite',
#  'allowed places were originally parks and public paths but now it s green and open spaces managed by the government so jogging around the neighbourhood is no longer ok but exercising in other open spaces is allowed of course the government is free to close access wherever it likes but you d be breaking the law by trespassing rather than contravening the covid regulations the required safe distance is 1 metre no matter whether you re exercising or not',
#  'where do you get your news bro alex tan',
#  'giving 50 bucks a day to singapore companies to house their malaysians employees for two weeks',
#  'yeah get those poors out of sg oh wait who will clean your toilets do your maid work and do construction work',
#  'these are also the people who will be first in the line to use the available medical facilities before the others who are more prudent and considerate',
#  'look on the bright side they can t do anymore harm if they re dead right',
#  'happy cake day',
#  'happy cake day',
#  'it s like the escooter all over again regulations not enough just outright ban lor',
#  'i d blame it on the government downplaying everything and trying to to raise the alarm bit by bit it will take time for people to adapt what s wrong with dorscon red and initiating a lockdown at the start we just love to blame the citizens here the government is never at fault',
#  'fair mah',
#  'this if u stick by this can t go wrong',
#  'no wor still got many needs to jog wor like no jog will die like that no jogging is more serious than keeping the virus in check ok',
#  'the closing of the recreational places is part of the gov s efforts to mitigate the spread of covid it is not at the discretion of the relevant park authorities',
#  'no longer allowing takeout',
#  'plus wear mask and 10m apart',
#  'i feel like some people just can t stand staying at home people who don t regularly exercise are using exercise as an excuse to step outside their homes and hogging all the public spaces i like to go for a jog around my estate and since the measures were implemented all the running routes have 2 3 times as many people entire families are exercising together even some parents are bringing their kids outside i m not sure if this is them being dumb or insensitive anyway i ll try to do my part by exercising at night or at dawn when there aren t people around failing which i ll just stay at home and workout indoors',
#  'agreed these people try to cover up their selfish wants by saying the law say can when they re definitely just toeing the line',
#  'they re a drain on our resources even before covid 19 the faster they go the better it is for the country',
#  'the problem is that they ll do quite a bit of harm before they die',
#  'sg gahmen dont play around which i like i give u chance but u want to cb me then i cb u back',
#  'i suppose it would be fair to say that the rules for caregiving have changed but for the other situations i don t see any change in rules the closing or beaches and park areas is not a change in rules but the discretion of the relevant park authority',
#  'try going before sunrise fresh air few to no one and you may be able to catch the sunrise before you head home',
#  'dumb i vote dumb',
#  'no no no you re forgetting the narrative that the government is an overbearing patriarchial tyrant',
#  'preach sistar',
#  'pass ippt my window open liao not v crowded what but i usually go at ard 8 9pm',
#  'this x200b now i change my timing esp since wfh and go earlier around 3 4pm hot afternoon much fewer people',
#  'first world country third world ability to understand instructions',
#  'they really are trying to play the system good to know the authorities are enforcing the law',
#  'covidiot can go out play play g go fly kite covidiot k',
#  'hastalawakbar have you been living in a cave omg',
#  'i m trying to think of an explanation to their defence i came up with none',
#  'can i borrow someone else s hands to face palm i don t have enough hands to face palm this level of stupidity',
#  'i think a lot of people lost the ability to understand the term staythef home',
#  'bird singing',
#  'i think it s referring to the hobby of rearing songbirds and there are parks that owners can hoist their birds in cages up high',
#  'that beach only has like 5 meters of sand',
#  'great',
#  'i know and i agree but i was curious as to the legality of it only',
#  'is using bicycle for getting necessities okay by the current law',
#  'serious q the covid 19 temporary measures act of 2020 aka circuit breaker legislation says that one of the allowed reasons to leave your home is d to engage in any recreational activity in an open air stadium public path or public park alone or with any other individual who lives with the firstmentioned individual https www moh gov sg docs librariesprovider5 pressroom press releases annex for notification 8 apr 2020 pdf doesn t this explicitly allow flying a kite or playing frisbee as long as you re doing it only with people you live with and keep a safe distance away from anybody else',
#  'good',
#  'whoa ccb 250 x 300 is already a small fortune',
#  'the national parks board nparks shared that they have closed more than 720 playgrounds and fitness corners to allow for safe distancing and prevent gatherings in groups',
#  'ccb 250 fines warnings issued to kite flying frisbee playing bird singing park visitors in s pore as of apr 11 around 250 written stern warnings and fines have been issued to visitors in parks managed by nparks and town councils public advised to stay at home to avoid spreading virus errant visitors were found exercising kite flying frisbee playing bird singing entering areas that had been closed groups of mountain bikers and cyclists were among the visitors as well in a response to mothership s queries the national parks board nparks shared that they have closed more than 720 playgrounds and fitness corners to allow for safe distancing and prevent gatherings in groups bookings for events and barbecue pits and camping permits have also been suspended sections of parks across singapore have also been closed off as part of safe distancing measures by nparks this includes the wetland centre in sungei buloh wetland reserve and bishan ang mo kio park the henderson waves as well as the macritchie treetop walk however nparks also said that they were encouraged that most visitors have been cooperative and understanding with the temporary measures in place and that visitorship in the parks has been relatively low to moderate beaches temporarily closed changi beach park east coast park pasir ris park punggol point sembawang park and west coast park have also been closed as part of measures to ensure safe distancing yesterday apr 11 minister for national development lawrence wong announced in a facebook post that all beaches have been closed and urged the public to stay at home as much as possible he also acknowledged that the current measures might feel too restrictive to others and added that this is a public health crisis and we have to do what is right and necessary to protect singaporeans wong mentioned that while most places can stay open they can only stay open if safe distancing measures are strictly adhered to however he mentioned that currently safe distancing measures are not strictly adhered to and that tougher measures are necessary he reminded everyone to stay at home as possible and only go out if it is absolutely necessary such as to buy food or to get groceries he asked everyone to wear a mask while going out and to go home once the task is complete top image via lawrence wong fb nparks 1 0 2 source code https github com fterh sneakpeek contribute https github com fterh sneakpeek',
#  'they got spare to donate to gov',
#  'national parks stated that all social group recreational activities such as picnics fishing group exercise etc are not permitted before you argue they might be doing all those activities alone you can fish alone too and that is prohibited so bird singing and kite flying is ok i doubt so and tbh do we really need a specific rule telling us not to play outside during this pandemic',
#  'why do people like to wait til laws are being enforced then they wake up their ideas and especially in tough times like this when we should bite tight together to go through this period if we were to compare with other countries that were being locked down allowing people to exercise is already a privilege and now we have people trying to test the system social responsibility is the keyword my friend',
#  'stay the fuck home you retards',
#  'i am not that surprised at this news even in this sub reddit there are already people thumbing down others for encouraging social distancing so you can take this mentality sample from this sub and extrapolate it to the real life',
#  'errant visitors were found exercising kite flying frisbee playing bird singing entering areas that had been closed aren t we supposed to be going to parks to exercise and isn t frisbee playing a good form of exercise as long as it s with family members',
#  'went here 30 years ago how far has sg progressed as a fine city now let me relek now as i enjoy my retirement elsewhere',
#  'by the looks of things in the news the ability to ignore laws in order to look out for the number one is a first world mentality too',
#  'i feel it s cos majority has this sense of exceptionalism like it won t happen to me kinda thinking as another poster said when the virus claims another victim no one really cares https www reddit com r singapore comments fyiuvd case_1604_who_tested_positive_for_covid19_after fn2oufy we can t seem to make the connection between our irresponsible behavior and the outcome the death of case xxx is just something we gloss over rather than taking the time to pause and reflect on our own behavior and reaction to this pandemic',
#  'so you say this and it s fine i said this a couple days back and got called sheltered',
#  'never been a fan of this distinction the system is made and used by the people there is no difference between the two',
#  'i saw one family flying kite in an open field between bishan and toa payoh this one unprecedented',
#  'but don t touch your face',
#  'there always are at the open areas at ecp popular spots would be angsana green and the concrete steps in front of the bougainvillea garden marina barrage as well but that s not a beach',
#  'i think now before stepping out of the house people just need to ask themselves one question is this essential',
#  'kite flying is not allowed but asking someone to do so is allowed',
#  'why do the police have a different set of laws maybe they work off channel news asia',
#  'if you go alone i don t see why not',
#  'remember to wear mask',
#  'why would anyone feel the need to fly a kite or play frisbee just because the legislation says you can doesn t mean you have to it s very simple stay home save lives',
#  'they probably the same people who yell govt give u 1 drumstick they take back 1 whole etc',
#  'had been closed you missed this part',
#  'some may be due to over zealous enforcement or instructions not clear also whether to stick to the letter or to the spirit of the rules this is like the no eating in rule enforcement that pushed f b workers to dine in toilets',
#  'https www nparks gov sg noticeboard https www nparks gov sg noticeboard',
#  'agreed i don t see the harm in doing so as long as it with family that you live with in a public park which appearss to be in line with what the current law is',
#  '227 951 members of which at least 4 000 people are online now not everyone here has the same opinion',
#  'why you so salty',
#  'embrace the downvotes',
#  'now that most people don t have to work or work from home they suddenly have a lot of time to do things they usually don t have time for not a good time to pick up an outdoor hobby though',
#  'the phrasing seems to suggest that entering areas that had been closed is a separate action from exercising that led to fines warnings it could just be mothership s wording though',
#  'says who',
#  'im pretty sure there are people doing exercise with friends which kinda defeats the purpose so the gahmen decided if u want to bend the rules then they just stop everyone completely lo',
#  'i would say the very first word errant as in errant visitors disagrees with your interpretation i read it as they all were somewhere they should not be doing x y or z',
#  'no idea where angsana green is but pretty sure flying kites is not allowed at the bougainvila garden',
# ...
#  'not rules but some faqs for ppl that need further gov direction direction for their specific situation eg divorc e elderly concerns etc https www moh gov sg covid 19 faqs',
#  'the funny thing is some one eddit have posted of photos of how some pcns are closed not sure if it s all but it s not in the news correct me if i m wrong even nparks website doesn t mention https www nparks gov sg gardens parks and nature park connector network notices the measures might be rolling out faster than the news can cover liao lolol',
#  'it just shows how messy the situation is',
#  'i ve no evidence but i d like to think that you receive a briefing leaflet when you re served with a stayathome order and then if the rules change while your subject to it you re in contact with the gahmen on a daily basis anyway as they check you re in place',
#  'just go straight to total lockdown do what china is doing getting people to buy food',
#  'just do the lockdown and be done with it',
#  'tbh if you stick by the request to stay at in your own home and don t head out unless you need to get food or medical care then you ll be fine it s those who are constantly trying to find the loopholes that ll find these almost daily new measures difficult to follow and worry about falling foul of them',
#  'unfortunately they only seem to send the updates at around 11am',
#  'once somebody tests the system tmr and kena jialat jialat the news will spread through the bwn boomer whatsapp network',
#  'we re making it up as we go depending on how things are on the ground',
#  'then so far the public will look for loopholes in what can be done i heard this a lot and it might have some truth to it of course my bigger issue is with the current change stating that there will be no warnings if you re expected to violate no rules and don t get a warning which i think helps to send a sign to those that don t care then you should make it easy to see the damn rules in one simple place i understand the spirit of the law but i also see this is as a potential way to pay a fee for things that potentially were still okay yesterday again if no warnings will be issued anymore fine away for violations but be transparent and open about what s the situation is is what i m saying',
#  'best thing about this rule is that it s timeless',
#  'i m subscribed and i don t see the new regulation to wear mask when going into supermarkets on the other hand i am reading too many comments suggesting self enforced rules no exercising outside i think op is right to raise as a concern',
#  'hi op i am also subscribed to the gov sg whatsapp bot and i am given to believe gov sg by its very name should be the best place to see a compilation of all the rulings issued by various agencies however you are right gov sg both the website and bot seem to be missing the latest advisories that came out today about compulsory wearing of masks on public transport wearing of masks to malls and supermarkets about the beach closures etc this suggests to me that the various agencies are coming up with these rules post haste as the situation evolves and there is no time to update gov sg website instead we need to rely on various sources like ministers fb postings reddit posts cna and st etc which i agree is kind of disorganised and scattered perhaps we can check back tomorrow or monday to see if gov sg is retroactively updated with today s snowstorm of announcements lets give gov sg a chance to get itself updated',
#  'i do understand where you are coming from but look at it from the other point of view the government say this cannot do that cannot do then so far the public will look for loopholes in what can be done i feel that yes there should be a proper official list but this list will be too dynamic for people to keep track anyway for example the mask is required for supermarkets convenience stores pharmacies and shopping malls and public transports i bet you singaporeans will be like then go to wet market no need to wear then the next thing you know government will say wer market also need then people will complain why keep changing the rules not reasonable to keep checking the list so it is more important for people try to follow the spirit of the law to the strictest interpretation which most likely will exceed the word of the law',
#  'i get what you are saying today was really a zerg rush of rules being published which contradicted what the ministers earlier preach this is totally uncharacteristic of past singapore s leadership style guess we ll just have to make peace with ourselves that a full lockdown is in effect immediately rather than trying to squeeze whatever remaining time we have with the outdoors',
#  'i d question why you aren t wearing a mask at this point in time just wear one whenever you go out can t go wrong',
#  'haha not gon as you to stay the hell at home but no i don t think theres a collated list of new updates to the rules it changes whenever the numbers are up or when ppl just not adhering to their rules and tries to find loopholes for me i will just bring my mask out in a ziplock bag and wear it when i have to esp when i m going into confined spaces like the mall or supermarkets even before the new rule kicked in',
#  'nah singaporeans are generally good and following rules and finding loopholes so this approach is really not going to work if the provided information is not crystal clear and communicated widely through all channels they can t go around enforcing it or they will face a pr backlash for poorly handling the situation especially if we are talking hundreds or thousands of especially old people who didn t get the message',
#  'your whole argument is based on this list will be too dynamic for people to keep track anyway i strongly disagree with that it feels like you spend 0 seconds thinking about it and just wrote something that looks like a reason to support your argument it s a matter of a few lines per day stop being of bad faith saying it would be worse than nothing',
#  'hey i m not sure if it fits the sub but i was wonder if i could go outside with my mom for her to visit the doctor we will be going in a cab and there were some rumours spreading around that two people can t go outside together please let me know i m a bit concerned due to the 300 fine thing that has started stay safe everyone and take care',
#  'you shouldn t be stopped as long as you re both from the same household i just accompany my mom to go for her regular check up today and there isn t any thing that s saying i can t do that',
#  'alternatively you can google teleconsulting and video chat with a doc the medicine will be couriered to you within 2 hours quoted time but i received mine in 30mins paid 18 consult delivery fee 30 1 course of anti biotics 48 this consultation was for uti it may be more expensive than polyclinic but polyclinic is heavily subsidised its equivalent to normal private doctors or even cheaper but you don t need to step out of your house',
#  'i believe you can check out under can i still accompany my elderly parent living in a different household to medical appointments https www gov sg article what you can and cannot do during the circuit breaker period just make sure you both put on a mask each and keep a safe distance from others',
#  'can if it s for a regular medical appointment you would have received a sms notification saying in part in dorscon orange only 1 person is allowed to accompany you to the clinic you may not be seen by your usual dr team of drs persons on shn will not be allowed entry if it s only for a regular doctor consultation i e not undergoing prior clinic test the health service will also suggest via sms skipping this turn if the illness isn t too critical am going through it with both my aged parents',
#  'i have an ob appointment and the doctor made it clear that one person can accompany me when i asked so i m sure you re good as long as it s not the whole family going together besides i m pretty sure the fines are targeted toward those loitering around and don t siam when asked to',
#  'as long as maximum 1 companion caregiver you re good don t loiter around after you re done',
#  'can two ppl go out together you must wear mask provided you live with your mum you may take her to the doctor but avoid doctor hopping',
#  'can',
#  'wow that s actually really smart thank you',
#  'according to straitstimes https www straitstimes com singapore transport carpooling now illegal after transport ministry waives exemption but largest lets say my colleagues and i just finish a meeting at some ulu place like tuas area so i can t take his car since we are heading east and have to take a cab else we will get fined 300 each',
#  'drivers are deemed to be carpooling if they use private cars and charge for ferrying passengers',
#  'i think walling off pay or not articles on revoked laws is a new low for straits times',
#  'forget about the law care more about your health and don t carpool 300 is nothing compared to you getting the virus and spreading it to others killing them',
#  'work harder so that u can afford to buy a car lol',
#  'but then below this includes non commercial carpool arrangements between people who do not live in the same residence',
#  'sorry but wouldn t carpool with a friend that you ve already been spending majority of your day at work with way better than taking the public transport with the crowds or taking grab uber with a stranger who ve picked up other passengers beforehand',
#  'another commenter said carpooling law does not apply to you in any case i think you can as it can be deemed to be reasonably related to your work in essential services',
#  'so basically it counts if you re paying regardless of whether it s on a platform or not',
#  'this is due to circuit breaker measure no you can t be in a car with someone not having same address as u',
#  'but how is the potential risk different from taxi grab wouldn t it increase the risk since now theres one more contact',
#  'as much as i agree on the severity of the virus situation i d say a lot of it is overplayed by how people fall into the trap of only being caught up by the big numbers they fail to see the details and composites of it of course that s also my personal opinion but i m here to just discuss how we can at least be more detail oriented in outlook recently there s been a massive spike in cases but if we look deeper the majority of the hundreds of new cases are really just the dorm workers this skews the data tremendously if we re only concerned about local transmissions outside the existing clusters which going by numbers tally are well basically made up mostly of the dorms anyway say for eg 400 new cases out of which 399 cases are quarantined already vs 400 new cases out of which only 100 cases are quarantined the number is the same but how we should treat the number should not be the same it s like how people panicked when we used to get a record 70 cases even though most were imported true the imported cases can still spread into locally transmitted cases but at present we dont know the likelihood of that there s also the factor of testing how many people are actually being tested matters just look at iran and their fake numbers if we didn t test all the dorm workers the daily numbers we see would probably be much much lower and regardless these workers being quarantined should raise no difference in whether their infections are added to the daily count or not i believe because the spread should already be contained to begin with lastly there are those who have already been quarantined and just tested after that in which case them adding to the infection count shouldn t matter as much either the ones we should be concerned about are the community transmissions which are honestly still significantly small in numbers if we take away those from existing clusters the number is even smaller if im not wrong only in a few or several dozens per day again i m not saying we re being over paranoid but it s important to look at the composition of a big number than just take it as face value in that case we can gauge the severity of the spread more accurately if we ever see a day of 1000 new cases or something before you go bonkers look deeper at the numbers edit i guess downvotes are downvotes seems like readers are getting the wrong message here i m not advocating to lessening our lockdown measures or anything all i m pointing out is the possibility for daily cases to drop drastically in the future not mainly because of cb measures but drop naturally because most cases that we see at the moment are all only from pre existing clusters and dormitories that are already quarantined and far far away from the general public once the dorm infections are over the total no of cases will likely drop so basically don t go bananas when you see today s 300 new cases',
#  'i feel the assessment is being too optimistic here cases will get more severe later for ventilators we have no idea how many we have it is not open information we have seen how breakdown in healthcare system has led to large increases in number of deaths including healthcare workers death which is extremely demoralising here s hoping we can avoid that',
#  'there s no exact number in fact no country gave up on efforts despite having dorscon red like situation',
#  'yes the numbers spike 5 days now coincides with the aggressive case finding mass swab testing of all workers living in purpose built workplace dorms since april 9 this taskforce involving the saf spf is led by tch my concern is that moh has currently named 24 dorm construction clusters but only 8 of them are declared as isolation areas s11 dorm tampines dorm sungei tengah lodge westlite toh guan toh guan dorm cochrane lodge 1 cochrane lodge 2 acacia lodge this means that those living at the other 18 clusters as well as at the other foreign worker accommodation mom lists 43 licensed dorm operators of 1 000 beds each they ve also inspected more than 600 other factory converted dorms in the last few days aren t subject to quarantine orders unless they are identified as close contacts the 24 workers getting deported for breaking cb measures at tuas view square dorm meaning they were caught mingling outside nearby highlight the social dilemma when the entire construction sector is halted at the same time i expect more dorms to be gazetted as isolation areas in the coming week rather than doing this piecemeal perhaps shn orders should be issued to every dorm resident instead cluster or no cluster otherwise we re just dragging out stopping the spread at these hot zones',
#  'i agree with you that the recent surge if contained within the dorms can be controlled and eventually brought down however imo the high numbers are still concerning bcos all the infected are still people as a thought experiment imagine if today s 386 cases are nsfs in tekong it would still be contained but the political fallout would be huge similarly we have to treat the fws as if they are singaporeans since they come here to work for us just my thoughts not finding issues with your points',
#  'fws vs singaporeans i have never mentioned anything along this line that s you it s clear you were trying to allude that things are not so bad because the growth of numbers are from fws and not locals this is clearly a destructive thinking to have right now',
#  'what i mean is that at least with current clusters you can take the steps to contain and ensure that it doesn t spread out if you get a totally new cluster you have to throw resources to ensure that it gets contained',
#  'huh what is dorscon red is new flavour can eat one ah you want try some pof ma ma',
#  'this is why higher number of cases regardless of their nature is so scary it pushes the healthcare system closer towards being overwhelmed',
#  ...]

# %%
cList = {
  "ain't": "am not",
  "aren't": "are not",
  "can't": "cannot",
  "can't've": "cannot have",
  "'cause": "because",
  "could've": "could have",
  "couldn't": "could not",
  "couldn't've": "could not have",
  "didn't": "did not",
  "doesn't": "does not",
  "don't": "do not",
  "hadn't": "had not",
  "hadn't've": "had not have",
  "hasn't": "has not",
  "haven't": "have not",
  "he'd": "he would",
  "he'd've": "he would have",
  "he'll": "he will",
  "he'll've": "he will have",
  "he's": "he is",
  "how'd": "how did",
  "how'd'y": "how do you",
  "how'll": "how will",
  "how's": "how is",
  "I'd": "I would",
  "I'd've": "I would have",
  "I'll": "I will",
  "I'll've": "I will have",
  "I'm": "I am",
  "I've": "I have",
  "isn't": "is not",
  "it'd": "it had",
  "it'd've": "it would have",
  "it'll": "it will",
  "it'll've": "it will have",
  "it's": "it is",
  "let's": "let us",
  "ma'am": "madam",
  "mayn't": "may not",
  "might've": "might have",
  "mightn't": "might not",
  "mightn't've": "might not have",
  "must've": "must have",
  "mustn't": "must not",
  "mustn't've": "must not have",
  "needn't": "need not",
  "needn't've": "need not have",
  "o'clock": "of the clock",
  "oughtn't": "ought not",
  "oughtn't've": "ought not have",
  "shan't": "shall not",
  "sha'n't": "shall not",
  "shan't've": "shall not have",
  "she'd": "she would",
  "she'd've": "she would have",
  "she'll": "she will",
  "she'll've": "she will have",
  "she's": "she is",
  "should've": "should have",
  "shouldn't": "should not",
  "shouldn't've": "should not have",
  "so've": "so have",
  "so's": "so is",
  "that'd": "that would",
  "that'd've": "that would have",
  "that's": "that is",
  "there'd": "there had",
  "there'd've": "there would have",
  "there's": "there is",
  "they'd": "they would",
  "they'd've": "they would have",
  "they'll": "they will",
  "they'll've": "they will have",
  "they're": "they are",
  "they've": "they have",
  "to've": "to have",
  "wasn't": "was not",
  "we'd": "we had",
  "we'd've": "we would have",
  "we'll": "we will",
  "we'll've": "we will have",
  "we're": "we are",
  "we've": "we have",
  "weren't": "were not",
  "what'll": "what will",
  "what'll've": "what will have",
  "what're": "what are",
  "what's": "what is",
  "what've": "what have",
  "when's": "when is",
  "when've": "when have",
  "where'd": "where did",
  "where's": "where is",
  "where've": "where have",
  "who'll": "who will",
  "who'll've": "who will have",
  "who's": "who is",
  "who've": "who have",
  "why's": "why is",
  "why've": "why have",
  "will've": "will have",
  "won't": "will not",
  "won't've": "will not have",
  "would've": "would have",
  "wouldn't": "would not",
  "wouldn't've": "would not have",
  "y'all": "you all",
  "y'alls": "you alls",
  "y'all'd": "you all would",
  "y'all'd've": "you all would have",
  "y'all're": "you all are",
  "y'all've": "you all have",
  "you'd": "you had",
  "you'd've": "you would have",
  "you'll": "you you will",
  "you'll've": "you you will have",
  "you're": "you are",
  "you've": "you have"
}
sorted_cList={}
for k in sorted(cList, key=len, reverse=True):
    sorted_cList[k] = cList[k]
c_re = re.compile('(%s)' % '|'.join(sorted_cList.keys()))

def expandContractions(text, c_re=c_re):
    def replace(match):
        return cList[match.group(0)]
    return c_re.sub(replace, text)

def remove_urls (s):
    s = re.sub(r"(?i)\b((?:[a-z][\w-]+:(?:/{1,3}|[a-z0-9%])|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:'\.,<>?«»“”‘’]))", '', s, flags=re.M)
    return(s)

# %%
contractions = [i for i in cList.keys()]

# %%
def correct_spelling(text,keep): #string, list of words to not change
    temp = []
    for word in text.split(' '):
        if (0.985 <= Word(word).spellcheck()[0][1] < 1.0) and word not in keep:
            w = Word(word).spellcheck()[0][0]
            temp.append(w)
        else:
            temp.append(word)
            
    return " ".join(temp)

# %%
wnl = nltk.stem.wordnet.WordNetLemmatizer()
wtk = nltk.tokenize.RegexpTokenizer(r'\w+')
# keep = ['kiasu','singlish'] #for all comments - check the different dataframes and change the list

def preprocess(listtexts,keep):
    stop_list = stopwords.words('english') + [i for i in string.punctuation] + contractions
#     l1 = []
#     l2 = []
    processed_texts = []
    tokens = []
    tokenised_form = []
    
    for text in listtexts:
        text = str(text)
        text = text.lower()
        text = re.sub(r'^https?:\/\/.*[\r\n]*', '', text, flags=re.MULTILINE)
        text = remove_urls(text)
        text = expandContractions(text)
        text = correct_spelling(text,keep)
        
        tokens = wtk.tokenize(text)
        tokens = [token for token in tokens if token not in stop_list]
        tokens = [token for token in tokens if len(token) != 1]
        tokens = [wnl.lemmatize(token) for token in tokens]
        tokens = [unicodedata.normalize("NFKD",word) for word in tokens]
#         tokens = [word.encode('ascii','ignore') for word in tokens]
        tokens = [word.encode('ascii','ignore').decode('utf-8') for word in tokens]
        
#         for i in tokens:
#             if i in l1:
#                 x = tokens.index(i)
#                 y = l1.index(i)
#                 tokens.remove(i)
#                 tokens.insert(x,l2[y])
                
        if len(tokens) != 0:
            processed = ' '.join(tokens)
            
            processed_texts.append(processed)
            tokenised_form.append(tokens)
        
    return processed_texts, tokenised_form

# %%
stop_list = stopwords.words('english') + [i for i in string.punctuation] + contractions

# %%
fine_clean, fine_tok = preprocess(fine,keep=[])

# %%
def remove_new_stopwords(list_texts,tokens,new_stop_words):
    temp = []
    temp_tok = []
    
    for i in list_texts:
        x = i.split(' ')
        for n in new_stop_words:
            if n in x:
                x.remove(n)
        temp.append(" ".join(x))
    
    for i in tokens:
        x = i
        for n in new_stop_words:
            if n in x:
                x.remove(n)
        temp_tok.append(x)
      
    return temp, temp_tok

# %%
new_stop_words = ['http','www','github','com']

fine_clean2, fine_tok2 = remove_new_stopwords(fine_clean, fine_tok, new_stop_words)

stopwords_list = stop_list + new_stop_words

# %% [markdown]
# fine          266
# mask          249
# people        232
# like          164
# one           154
# time          152
# get           133
# also          124
# order         115
# would         110
# think         109
# go            107
# singapore     106
# worker        106
# need           98
# even           95
# wear           92
# said           91
# measure        91
# home           91
# still          90
# food           88
# 300            83
# government     80
# see            78

# %% [markdown]
# # Word Frequency

# %%
from nltk.probability import FreqDist

# %%
def word_freq(tok):
    list_of_words = []
    for i in tok:
        list_of_words += i
        
    fdist = FreqDist(list_of_words)
#     print(fdist.most_common()[:10],'\n')
    common_words = fdist.most_common()[:50]
    print(common_words)
    
    bgs = nltk.bigrams(list_of_words)
    fdist2 = nltk.FreqDist(bgs)
#     print(fdist2.most_common()[:10],'\n')
    common_bigrams = fdist2.most_common()[:20]
    print('\n',common_bigrams)
    
#     tgs = nltk.trigrams(list_of_words)
#     fdist3 = nltk.FreqDist(tgs)
#     print(fdist3.most_common()[:10])
    
    return common_words, common_bigrams

# %%
fine_words, fine_bigrams = word_freq(fine_tok)
# Out:
# [('fine', 266), ('mask', 249), ('people', 232), ('like', 164), ('one', 154), ('time', 152), ('get', 133), ('also', 124), ('http', 121), ('order', 115), ('would', 110), ('think', 109), ('go', 107), ('singapore', 106), ('worker', 106), ('need', 98), ('even', 95), ('wear', 92), ('measure', 91), ('said', 91), ('home', 91), ('still', 90), ('food', 88), ('300', 83), ('com', 82), ('government', 80), ('see', 78), ('rule', 75), ('case', 74), ('thing', 73), ('know', 73), ('take', 73), ('going', 73), ('public', 71), ('delivery', 71), ('say', 70), ('rider', 69), ('day', 66), ('covid', 65), ('really', 64), ('safe', 63), ('already', 63), ('right', 63), ('dorm', 63), ('first', 62), ('distancing', 62), ('place', 62), ('make', 62), ('work', 62), ('company', 62)]
#
#  [(('wear', 'mask'), 69), (('http', 'www'), 62), (('safe', 'distancing'), 47), (('covid', '19'), 42), (('wearing', 'mask'), 40), (('circuit', 'breaker'), 39), (('gov', 'sg'), 37), (('stay', 'home'), 31), (('http', 'github'), 27), (('github', 'com'), 27), (('com', 'fterh'), 26), (('fterh', 'sneakpeek'), 26), (('distancing', 'measure'), 24), (('fine', '300'), 23), (('com', 'singapore'), 22), (('300', 'fine'), 21), (('foreign', 'worker'), 20), (('hawker', 'centre'), 18), (('reusable', 'mask'), 17), (('essential', 'service'), 17)]

# %%
fine_words2, fine_bigrams2 = word_freq(fine_tok2)
# Out:
# [('fine', 266), ('mask', 249), ('people', 232), ('like', 164), ('one', 154), ('time', 152), ('get', 133), ('also', 124), ('order', 115), ('would', 110), ('think', 109), ('go', 107), ('singapore', 106), ('worker', 106), ('need', 98), ('even', 95), ('wear', 92), ('measure', 91), ('said', 91), ('home', 91), ('still', 90), ('food', 88), ('300', 83), ('government', 80), ('see', 78), ('rule', 75), ('case', 74), ('thing', 73), ('know', 73), ('take', 73), ('going', 73), ('public', 71), ('delivery', 71), ('say', 70), ('rider', 69), ('day', 66), ('covid', 65), ('really', 64), ('safe', 63), ('already', 63), ('right', 63), ('dorm', 63), ('first', 62), ('distancing', 62), ('place', 62), ('make', 62), ('work', 62), ('company', 62), ('could', 60), ('wearing', 59)]
#
#  [(('wear', 'mask'), 69), (('safe', 'distancing'), 47), (('covid', '19'), 42), (('wearing', 'mask'), 40), (('circuit', 'breaker'), 39), (('gov', 'sg'), 37), (('stay', 'home'), 31), (('fterh', 'sneakpeek'), 26), (('http', 'www'), 25), (('distancing', 'measure'), 24), (('fine', '300'), 23), (('300', 'fine'), 21), (('foreign', 'worker'), 20), (('hawker', 'centre'), 18), (('reusable', 'mask'), 17), (('essential', 'service'), 17), (('people', 'wear'), 16), (('bank', 'account'), 15), (('first', 'time'), 13), (('social', 'distancing'), 13)]

# %% [markdown]
# # Word Cloud

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
def word_cloud(common_words,type):
    common = ''
    for i in common_words:
        common += i[0] + ' '
        
    wordcloud = WordCloud(background_color="white", width=1600, height=800, max_font_size=200).generate(common)

    plt.imshow(wordcloud, interpolation ='bilinear')
    plt.axis("off")
    plt.show()
    
    wordcloud.to_file("C:/Users/user/Downloads/IS434 (SA)/Project/ProjectCloud/fine_{}.png".format(type))
    
    return None

# %%
def word_cloud_bigrams(common_bigrams,type):
    common = ''
    for i in common_bigrams:
        common += "_".join(i[0]) + ' '
        
    wordcloud = WordCloud(background_color="white", width=1600, height=800, max_font_size=200).generate(common)

    plt.imshow(wordcloud, interpolation ='bilinear')
    plt.axis("off")
    plt.show()
    
    wordcloud.to_file("C:/Users/user/Downloads/IS434 (SA)/Project/ProjectCloud/fine_{}.png".format(type))
    
    return None

# %%
word_cloud(fine_words,"words")

# %%
word_cloud(fine_words2,"words2")

# %%
word_cloud_bigrams(fine_bigrams, 'bigrams')

# %%
word_cloud_bigrams(fine_bigrams2, 'bigrams2')

# %% [markdown]
# # Topic Modelling

# %%
## Your code. Create vector object here ##
cv = CountVectorizer()
count_vect = cv.fit_transform(fine_clean2)

# %%
vocab = cv.get_feature_names()
print("Number of features :\n", len(vocab))
cv_matrix = count_vect.toarray()
vect_df = pd.DataFrame(cv_matrix, columns=vocab)
vocab_s1 = vect_df.sum(axis = 0)
vocab_sorted = vocab_s1.sort_values(ascending=False)
vocab_sorted.head(25)
# Out:
# Number of features :
#  5365
# fine          266
# mask          249
# people        232
# like          164
# one           154
# time          152
# get           133
# also          124
# order         115
# would         110
# think         109
# go            107
# singapore     106
# worker        106
# need           98
# even           95
# wear           92
# said           91
# measure        91
# home           91
# still          90
# food           88
# 300            83
# government     80
# see            78
# dtype: int64

# %%
from nltk.tokenize import word_tokenize

tokenised_pt = [word_tokenize(i) for i in fine_clean2]
# tokenised_pt = tok

# %%
dictionary = gensim.corpora.Dictionary(tokenised_pt)
print('Sample word to number mappings:', list(dictionary.items())[:15])
print('Total Vocabulary Size:', len(dictionary))
dictionary.filter_extremes(no_below=3)
corpus_vect = [dictionary.doc2bow(text) for text in tokenised_pt]
# Out:
# Sample word to number mappings: [(0, '14'), (1, '300'), (2, 'age'), (3, 'april'), (4, 'artofvisuals'), (5, 'child'), (6, 'circuitbreakersg'), (7, 'citygrammers'), (8, 'conference'), (9, 'coronavirus'), (10, 'covi'), (11, 'curb'), (12, 'd19'), (13, 'development'), (14, 'effect')]
# Total Vocabulary Size: 5371

# %%
from gensim.models import CoherenceModel

perplexity_list = []
coherence_list = []
num_topics = range(1,11)

for i in num_topics:
    ldamodel = LdaModel(corpus_vect, num_topics = i, id2word=dictionary, passes=50, random_state= 0)
    
    log_perplexity = ldamodel.log_perplexity(corpus_vect)
    perplexity = 2**(-log_perplexity)
    perplexity_list.append(perplexity)
    
    coherence_model_lda = CoherenceModel(model=ldamodel, texts=tokenised_pt, dictionary=dictionary, coherence='c_v')
    coherence_lda = coherence_model_lda.get_coherence()
#     print(coherence_lda)
    coherence_list.append(coherence_lda)
    

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.plot(num_topics,perplexity_list, marker='o', color =  'r')
ax2.plot(num_topics, coherence_list, marker = 'o', color = 'b')

ax1.set_xlabel('Number of topics')
ax1.set_ylabel('Perplexity', color = 'r')
ax2.set_ylabel('Coherence', color = 'b')

# plt.plot(num_topics, perplexity_list, marker='o')
# plt.xlabel('Number of topics')
# plt.ylabel('Perplexity') 
plt.show()

# %%
ldamodel = LdaModel(corpus_vect, num_topics = 5, id2word=dictionary, passes=50, random_state= 0)

# %%
#formatting the topics in print
for num ,topic in ldamodel.show_topics(formatted=True, num_topics=5, num_words=10):
    print(str(num)+": "+ topic + "\n\n")
# Out:
# 0: 0.033*"fine" + 0.012*"distancing" + 0.012*"safe" + 0.012*"measure" + 0.011*"said" + 0.009*"300" + 0.007*"day" + 0.007*"market" + 0.007*"hawker" + 0.007*"police"
#
#
# 1: 0.018*"worker" + 0.016*"dorm" + 0.014*"time" + 0.014*"cost" + 0.011*"would" + 0.011*"company" + 0.008*"better" + 0.008*"think" + 0.008*"pay" + 0.007*"one"
#
#
# 2: 0.022*"order" + 0.013*"delivery" + 0.013*"like" + 0.013*"rider" + 0.013*"food" + 0.010*"customer" + 0.009*"would" + 0.009*"restaurant" + 0.009*"time" + 0.008*"even"
#
#
# 3: 0.041*"mask" + 0.028*"people" + 0.017*"wear" + 0.014*"fine" + 0.011*"go" + 0.010*"like" + 0.010*"need" + 0.010*"one" + 0.009*"get" + 0.008*"say"
#
#
# 4: 0.015*"singapore" + 0.011*"sg" + 0.011*"gov" + 0.009*"http" + 0.008*"government" + 0.007*"singaporean" + 0.007*"fine" + 0.007*"work" + 0.007*"need" + 0.007*"com"
